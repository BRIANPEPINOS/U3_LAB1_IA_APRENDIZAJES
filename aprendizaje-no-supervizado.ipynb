# %% [markdown]
# <h3>Carga y preparación de los datos</h3>

# %%
import pandas as pd

from sklearn.preprocessing import StandardScaler

# Cargar dataset
df = pd.read_csv("creditcard.csv")

# Etiquetas reales (solo para evaluación)
y_true = df["Class"]

# Datos sin etiqueta
X = df.drop("Class", axis=1)

# Escalado de datos
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# <h3>Función de evaluación</h3>

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def evaluar_modelo(nombre, y_true, y_pred):
    print(f"\nModelo: {nombre}")
    print("Accuracy :", accuracy_score(y_true, y_pred))
    print("Precision:", precision_score(y_true, y_pred))
    print("Recall   :", recall_score(y_true, y_pred))
    print("F1-score :", f1_score(y_true, y_pred))

# %% [markdown]
# <h3>Implementación de algoritmos no supervisados</h3>

# %% [markdown]
# <h3>Isolation Forest</h3>

# %%
from sklearn.ensemble import IsolationForest

iso = IsolationForest(
    contamination=0.0017,
    random_state=42
)

y_pred_iso = iso.fit_predict(X_scaled)
y_pred_iso = (y_pred_iso == -1).astype(int)

evaluar_modelo("Isolation Forest", y_true, y_pred_iso)

# %% [markdown]
# <h3>Local Outlier Factor (LOF)</h3>

# %%
from sklearn.neighbors import LocalOutlierFactor

lof = LocalOutlierFactor(
    n_neighbors=20,
    contamination=0.0017
)

y_pred_lof = lof.fit_predict(X_scaled)
y_pred_lof = (y_pred_lof == -1).astype(int)

evaluar_modelo("Local Outlier Factor", y_true, y_pred_lof)

# %% [markdown]
# <h3>One-Class SVM</h3>

# %%
from sklearn.svm import OneClassSVM

ocsvm = OneClassSVM(
    kernel="rbf",
    gamma="scale",
    nu=0.0017
)

y_pred_ocsvm = ocsvm.fit_predict(X_scaled)
y_pred_ocsvm = (y_pred_ocsvm == -1).astype(int)

evaluar_modelo("One-Class SVM", y_true, y_pred_ocsvm)
